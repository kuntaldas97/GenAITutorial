# %% [markdown]
# ### Magic Methods
#
# Magic methods in Python, also known as dunder methods (double underscore mathods), are special methods that start and end with double underscores. These methods enable you to define the behavior of objects for buit-in operations, such as arithmetic operations, comparisons, and more.

# %% [markdown]
# ### Magic Methods
#
# Magic methods are predefined methods in Python that you can override to change the behavior of your objects. Some common magic methods include:

# %%
''' 1.__init__: Initializes a new instance of a class.
    2.__str__: Returns a string representation of an object.
    3.__repr__: Returns an official string representation of an object.
    4.__len__: Returns the length of an object.
    5.__getitem__:Gets an item from a container.
    6.__setitem__:Sets an item in a container.
    '''

# %%
## Basic Methoods
class Person:
    def __init__(self,name,age):
      self.name=name
      self.age=age
person=Person("Kuntal",28)

print(person)

# %%
## Basic Methoods
class Person:
    def __init__(self,name,age):
      self.name=name
      self.age=age
    def __str__(self):
       return f"{self.name},{self.age} years old"
    
    def __repr__(self):
       return f"Person(name={self.name},age={self.age})"
person=Person("Kuntal",28)
print(person)
print(repr(person))
# Out:
# Kuntal,28 years old
# Person(name=Kuntal,age=28)
