# %% [markdown]
# #### Importing Modules in Python: Modules and Packages
#
# In Python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np ## this can throw  error in VS code coz numpy is not install
## process to install numpy
##PYTHON->venv->requirement.txt -> write numpy->Open terminal -> cd..(come back to PYTHON directory)->pip install numpy

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(6))
print(pi)
# Out:
# 2.449489742783178
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(2,3)
# Out:
# 5
